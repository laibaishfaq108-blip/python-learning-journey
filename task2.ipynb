# %%
#WAR to input users first name and print its length.
name=input("Enter your name:")
len=len(name)
print("Length of your name is",len)
# Out:
# Enter your name:Laiba
# Length of your name is 5

# %%
#WAP to find the occurence of'$' in a string.
str="Hi $ am also a $ symbol $.99"
print(str.count("$"))
# Out:
# 3

# %%
#WAP to check if a number entered by the user is odd or even.
n=int(input("Enter a number:"))
if(n%2==0):
  print("given number is even.")
else:
  print("given number is odd.")
# Out:
# Enter a number:68
# given number is even.

# %%
#WAP to find the greatest of 3 numbers entered by user.
a=int(input("Enter 1st num:"))
b=int(input("Enter 2nd num:"))
c=int(input("Enter 3rd num:"))
if(a>b and a>c):
  print("a is the largest num.")
elif(b>c):
  print("b is the largest num.")
else:
  print("c is the largest num.")
# Out:
# Enter 1st num:8
# Enter 2nd num:9
# Enter 3rd num:2
# b is the largest num.

# %%
#WAP to check if a number is a multiple of 7 or not.
n=int(input("Enter a number:"))
if(n%7==0):
  print("Multiple of 7")
else:
  print("Not multiple of 7")
# Out:
# Enter a number:81
# Not multiple of 7
